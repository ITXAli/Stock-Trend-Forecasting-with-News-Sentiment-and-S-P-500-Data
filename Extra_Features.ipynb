# %%
import pandas as pd

print("Starting engineering of 'text_length' and 'word_count' features...")

# --- Load the dataset ---
try:
    data = pd.read_csv('stock(updated).csv')
    print("Dataset 'stock(updated).csv' loaded successfully.")
except FileNotFoundError:
    print("Error: 'stock(updated).csv' not found. Make sure it's in the same directory.")
    exit()

# --- Ensure 'combined_text' column exists ---
# This is crucial for calculating text_length and word_count consistently.
# It uses .fillna('') to handle potential missing values in headline/short_description.
if 'combined_text' not in data.columns:
    print("Creating 'combined_text' column...")
    data['combined_text'] = data['headline'].fillna('') + ' ' + data['short_description'].fillna('')
else:
    print("'combined_text' column already exists.")

# --- Engineer 'text_length' feature ---
print("Engineering 'text_length' feature...")
data['text_length'] = data['combined_text'].apply(len)
print(f"Sample 'text_length' values:\n{data['text_length'].head()}")

# --- Engineer 'word_count' feature ---
print("Engineering 'word_count' feature...")
data['word_count'] = data['combined_text'].apply(lambda x: len(x.split()))
print(f"Sample 'word_count' values:\n{data['word_count'].head()}")

# --- Save the updated DataFrame back to CSV ---
data.to_csv('stock(updated).csv', index=False)
print("\nFeatures 'text_length' and 'word_count' (and 'combined_text' if new) successfully engineered and saved back to 'stock(updated).csv'.")
print(f"Updated DataFrame shape: {data.shape}")
print(f"Updated DataFrame columns: {data.columns.tolist()}")
# Out:
# Starting engineering of 'text_length' and 'word_count' features...
# Dataset 'stock(updated).csv' loaded successfully.
# 'combined_text' column already exists.
# Engineering 'text_length' feature...
# Sample 'text_length' values:
# 0    231
# 1    249
# 2    234
# 3    233
# 4    187
# Name: text_length, dtype: int64
# Engineering 'word_count' feature...
# Sample 'word_count' values:
# 0    40
# 1    41
# 2    36
# 3    39
# 4    31
# Name: word_count, dtype: int64
#
# Features 'text_length' and 'word_count' (and 'combined_text' if new) successfully engineered and saved back to 'stock(updated).csv'.
# Updated DataFrame shape: (1759, 5015)
# Updated DataFrame columns: ['link', 'headline', 'category', 'short_description', 'authors', 'date', 'Close_^GSPC', 'High_^GSPC', 'Low_^GSPC', 'Open_^GSPC', 'Volume_^GSPC', 'combined_text', 'sentiment_score', '000', '10', '100', '101', '11', '12', '125', '13', '130', '14', '147', '15', '150', '16', '17', '18', '19', '1982', '1983', '1986', '1st', '20', '200', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2024', '206', '21', '22', '23', '24', '25', '250', '27', '28', '29', '2nd', '30', '300', '31', '32', '34', '35', '36', '37', '3rd', '40', '400', '43', '430', '44', '47', '4th', '50', '500', '52', '57', '59', '60', '63', '65', '66', '70', '75', '80', '800', '84', '850', '90', '94', '99', 'aaron', 'abandon', 'abandoned', 'abbott', 'abdullah', 'abe', 'abetting', 'abolish', 'abortion', 'abortions', 'abrams', 'abroad', 'absent', 'absolutely', 'abuse', 'abuses', 'accent', 'accept', 'accepted', 'accepting', 'access', 'accessory', 'accident', 'according', 'account', 'accountable', 'accounts', 'accusations', 'accuse', 'accused', 'accuser', 'accuses', 'aches', 'acknowledged', 'act', 'acted', 'acting', 'action', 'actions', 'activist', 'activists', 'activities', 'actor', 'acts', 'actual', 'actually', 'ad', 'adam', 'add', 'added', 'adding', 'additional', 'address', 'addressing', 'adds', 'adequately', 'administered', 'administration', 'administrator', 'admissions', 'admit', 'admits', 'admitted', 'admitting', 'ads', 'adults', 'advance', 'advice', 'adviser', 'advisers', 'advisory', 'advocates', 'affected', 'affidavit', 'affordable', 'afghan', 'afghanistan', 'afl', 'africa', 'african', 'ag', 'age', 'agencies', 'agency', 'agenda', 'agent', 'agents', 'ago', 'agree', 'agreed', 'agreement', 'agrees', 'ahead', 'ahmaud', 'aid', 'aide', 'aides', 'aiding', 'aim', 'aimed', 'aiming', 'aims', 'air', 'aircraft', 'airline', 'airlines', 'airport', 'airstrikes', 'al', 'alabama', 'alarm', 'alaska', 'alcohol', 'alec', 'alex', 'alexander', 'alexandria', 'alexei', 'alive', 'allegations', 'alleged', 'allegedly', 'alleges', 'alleging', 'allen', 'alliance', 'allies', 'allow', 'allowed', 'allowing', 'allows', 'alpine', 'alternative', 'amazon', 'ambassador', 'amendment', 'america', 'american', 'americans', 'amid', 'amy', 'ana', 'analysis', 'anchor', 'anderson', 'andre', 'andrew', 'andy', 'angeles', 'angeli', 'angels', 'angry', 'animal', 'animals', 'anniversary', 'announce', 'announced', 'announcement', 'announces', 'annual', 'answer', 'answered', 'anthony', 'anti', 'anticipating', 'antonio', 'antony', 'antónio', 'anubis', 'anxiety', 'anymore', 'ap', 'apart', 'apartment', 'apologized', 'apologizes', 'apology', 'app', 'apparent', 'apparently', 'appeal', 'appeals', 'appear', 'appearance', 'appeared', 'appears', 'applauded', 'apple', 'applicants', 'applications', 'apply', 'appointment', 'approach', 'approaches', 'appropriate', 'approval', 'approve', 'approved', 'approves', 'april', 'arab', 'arabia', 'arbery', 'arbitration', 'area', 'areas', 'aren', 'argued', 'argues', 'arguing', 'argument', 'arguments', 'arizona', 'arkansas', 'arm', 'armed', 'arms', 'army', 'arna', 'arrest', 'arrested', 'arrests', 'arrived', 'arrives', 'arrow', 'arson', 'artemis', 'arthur', 'articles', 'asap', 'asia', 'asian', 'aside', 'ask', 'asked', 'asking', 'asks', 'assad', 'assassination', 'assault', 'assaulting', 'assaults', 'assembly', 'assistance', 'assistant', 'associated', 'associates', 'association', 'assured', 'astrazeneca', 'astronaut', 'asylum', 'asymptomatic', 'athlete', 'athletes', 'atlanta', 'attack', 'attacked', 'attacks', 'attempt', 'attempted', 'attempting', 'attempts', 'attend', 'attendant', 'attendants', 'attended', 'attending', 'attention', 'attorney', 'attorneys', 'auction', 'audience', 'audits', 'august', 'aung', 'aunt', 'austin', 'australian', 'author', 'authoritarian', 'authorities', 'authority', 'authorizes', 'authors.1', 'available', 'avant', 'avenatti', 'avert', 'averting', 'avoid', 'awaited', 'awakened', 'award', 'awarded', 'awards', 'aware', 'away', 'awfu ...
